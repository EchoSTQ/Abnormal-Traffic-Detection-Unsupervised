# %%
import tqdm
import time
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, OneHotEncoder
from mpl_toolkits import mplot3d
from tensorflow.keras.layers import Input, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
from scipy.spatial.distance import euclidean
import random
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix

# %%
# 手动添加特征，训练集42，测试集41

feather = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 
           'num_failed_logins', 'logged_in', 'lnum_compromised', 'lroot_shell', 'lsu_attempted', 'lnum_root', 'lnum_file_creations', 
           'lnum_shells', 'lnum_access_files', 'lnum_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 
           'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 
           'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 
           'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'label']

# %%
# TRAIN_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\UNSW-NB 15\\UNSW_NB15_training-set.csv'
TRAIN_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\kddcup\\train_10_percent_kddcup.csv'
TEST_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\kddcup\\test_10_percent_kddcup.csv'

# %%
train_df = pd.read_csv(TRAIN_DATA_PATH, header = None, names = feather)
test_df = pd.read_csv(TEST_DATA_PATH, header = None, names = feather)
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# train
pd.value_counts(train_df['label']).plot(kind = 'bar', figsize = (20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize = 13)
plt.grid()
plt.show()

# %%
# 数据包含不同类型的服务，只考虑"http"服务，因为它是最常见的
print('different types of services:{}'.format(train_df['service'].unique()))

# 'http'数字转换后对应21
# train_df_http = train_df[(train_df['service'] == 21)]
# Out:
# different types of services:[21 52 15  9  1 58 16 11 41 12 42 47 45 17 50 61 33 31 49 18 54 34 67  8
#  32 25  6  5 40 51 26 39 23 14 46 13  3 64 28 29 10  7 57 56 27 20  4 44
#  55 65 36 37 35 53 66  2 69 30 38 62 68 63 43 59 60 48]

# %%
train_df_http = train_df

# %%
pd.value_counts(train_df_http['label']).plot(kind = 'bar', figsize = (20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize = 13)
plt.grid()
plt.show()

# %%
train_normal_instances = train_df_http[train_df_http['label'] == 0].shape[0]
train_anomalous_instances = train_df_http[train_df_http['label'] != 0].shape[0]

# 只提取属于"normal"的实例
train_df_http_normal = train_df_http[train_df_http['label'] == 0]

# 删除所有分类列
train_df_http_normal.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'label'], axis = 1, inplace = True)
# 删除无标准偏差的列
train_df_http_normal.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'lsu_attempted', 'lnum_file_creations', 'lnum_outbound_cmds'], axis = 1, inplace = True)

train_df_http_normal.boxplot(figsize = (20, 10))
plt.show()
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# train
# 热图，描述各个特征之间存在的相关性
scaler = StandardScaler()
train_df_http_normal = pd.DataFrame(scaler.fit_transform(train_df_http_normal), columns = train_df_http_normal.columns)

plt.figure(figsize = (15, 10))
sns.heatmap(train_df_http_normal.corr(), cmap = 'viridis')
plt.show()

# %%
# train
# 采用主成分分析法对数据进行降维，覆盖原始数据80%的方差
# ｎ＿components：指定希望PCA降维后的特征维度数目
# 最常用的做法是直接指定降维到的维度数目，此时n_components是一个大于等于1的整数。
# 当然，我们也可以指定主成分的方差和所占的最小比例阈值，让PCA类自己去根据样本特征方差来决定降维到的维度数，
# 此时n_components是一个（0，1]之间的数。
pca = PCA(n_components = 0.8)
pca.fit(train_df_http_normal)

pca_cols = ['PCA_' + str(i) for i in range(pca.n_components_)]
train_df_pca = pd.DataFrame(pca.transform(train_df_http_normal), columns = pca_cols)

# %%
train_df_http_normal.shape
# Out:
# (97278, 28)

# %%
train_df_pca.shape
# Out:
# (97278, 12)

# %%
# 采用特定的窗口长度和步长从数据中提取窗口
def get_windows(df, window_size = 10, stride = 5) :
    windows_arr = []
    for i in tqdm.tqdm(range(0, len(df) - window_size + 1, stride)) :
        windows_arr.append(df.iloc[i : i + window_size, : ].to_numpy())
        
    return np.array(windows_arr)

# %%
K.clear_session()

# 带堆叠LSTM的编码器模型
window_size = 10
encoder = Sequential([LSTM(80, return_sequences = True, activation = 'selu', input_shape = (window_size, 12), dropout = 0.2), 
                      LSTM(50, activation = 'selu', return_sequences = True), 
                      LSTM(20, activation = 'selu')], name = 'encoder')


# 输出维与输入维相同的解码器模型
decoder = Sequential([RepeatVector(window_size), 
                      LSTM(50, activation = 'selu', return_sequences = True), 
                      LSTM(80, activation = 'selu', return_sequences = True), 
                      TimeDistributed(Dense(12, activation = 'linear'))], name = 'decoder')

# 使用编码器、解码器作为层创建顺序自动编码器
autoencoder = Sequential([encoder, decoder], name = 'autoencoder')
autoencoder.compile(optimizer = 'adam', loss = tf.keras.losses.Huber(100.))
autoencoder.summary()

encoder.summary()
decoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Sequential)         (None, 20)                61640
# _________________________________________________________________
# decoder (Sequential)         (None, 10, 12)            57092
# =================================================================
# Total params: 118,732
# Trainable params: 118,732
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 80)            29760
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 50)            26200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20)                5680
# =================================================================
# Total params: 61,640
# Trainable params: 61,640
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# repeat_vector (RepeatVector) (None, 10, 20)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 50)            14200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10, 80)            41920
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 12)            972
# =================================================================
# Total params: 57,092
# Trainable params: 57,092
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 训练自编码器
# 训练时使用模型checkpoint回调，以保证在验证集上具有最佳性能的模型和权重
check_point = tf.keras.callbacks.ModelCheckpoint('autoencoder.h5', monitor = 'val_loss', save_best_only = True, mode = 'min', verbose = 1)
windows_shuffled = get_windows(train_df_pca)

# 记录训练时间
start_time=time.clock()
train_hist = autoencoder.fit(windows_shuffled, windows_shuffled[:, :, ::-1], batch_size = 64, validation_split = 0.15, epochs = 50, callbacks = [check_point])
end_time=time.clock()

print("train time : ", (end_time - start_time))

# 用最佳权重集加载自动编码器
autoencoder_loaded = tf.keras.models.load_model('autoencoder.h5')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 19454/19454 [00:01<00:00, 10414.33it/s]
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# Train on 16535 samples, validate on 2919 samples
# Epoch 1/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.5757
# Epoch 00001: val_loss improved from inf to 0.51622, saving model to autoencoder.h5
# 16535/16535 [==============================] - 29s 2ms/sample - loss: 0.5757 - val_loss: 0.5162
# Epoch 2/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4993
# Epoch 00002: val_loss improved from 0.51622 to 0.49594, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4993 - val_loss: 0.4959
# Epoch 3/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4959
# Epoch 00003: val_loss improved from 0.49594 to 0.45001, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4959 - val_loss: 0.4500
# Epoch 4/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4626
# Epoch 00004: val_loss improved from 0.45001 to 0.44320, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4622 - val_loss: 0.4432
# Epoch 5/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4521
# Epoch 00005: val_loss did not improve from 0.44320
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4530 - val_loss: 0.4435
# Epoch 6/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4463
# Epoch 00006: val_loss improved from 0.44320 to 0.43429, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4464 - val_loss: 0.4343
# Epoch 7/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4344
# Epoch 00007: val_loss improved from 0.43429 to 0.42765, saving model to autoencoder.h5
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.4341 - val_loss: 0.4277
# Epoch 8/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4231
# Epoch 00008: val_loss improved from 0.42765 to 0.40850, saving model to autoencoder.h5
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.4228 - val_loss: 0.4085
# Epoch 9/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4184
# Epoch 00009: val_loss improved from 0.40850 to 0.39822, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4179 - val_loss: 0.3982
# Epoch 10/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4086
# Epoch 00010: val_loss did not improve from 0.39822
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.4084 - val_loss: 0.4071
# Epoch 11/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3962
# Epoch 00011: val_loss improved from 0.39822 to 0.36674, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3972 - val_loss: 0.3667
# Epoch 12/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.4012
# Epoch 00012: val_loss did not improve from 0.36674
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.4020 - val_loss: 0.3776
# Epoch 13/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3946
# Epoch 00013: val_loss did not improve from 0.36674
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3950 - val_loss: 0.3709
# Epoch 14/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3851
# Epoch 00014: val_loss improved from 0.36674 to 0.36143, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3847 - val_loss: 0.3614
# Epoch 15/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3849
# Epoch 00015: val_loss improved from 0.36143 to 0.35510, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3851 - val_loss: 0.3551
# Epoch 16/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3660
# Epoch 00016: val_loss did not improve from 0.35510
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.3657 - val_loss: 0.3659
# Epoch 17/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3632
# Epoch 00017: val_loss improved from 0.35510 to 0.32260, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3632 - val_loss: 0.3226
# Epoch 18/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3544
# Epoch 00018: val_loss did not improve from 0.32260
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.3540 - val_loss: 0.3574
# Epoch 19/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3504
# Epoch 00019: val_loss did not improve from 0.32260
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3501 - val_loss: 0.3301
# Epoch 20/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3211
# Epoch 00020: val_loss improved from 0.32260 to 0.30833, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3209 - val_loss: 0.3083
# Epoch 21/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3284
# Epoch 00021: val_loss did not improve from 0.30833
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.3288 - val_loss: 0.3217
# Epoch 22/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3063
# Epoch 00022: val_loss improved from 0.30833 to 0.29340, saving model to autoencoder.h5
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.3062 - val_loss: 0.2934
# Epoch 23/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2938
# Epoch 00023: val_loss improved from 0.29340 to 0.28810, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2935 - val_loss: 0.2881
# Epoch 24/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3315
# Epoch 00024: val_loss did not improve from 0.28810
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3312 - val_loss: 0.3076
# Epoch 25/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3000
# Epoch 00025: val_loss improved from 0.28810 to 0.26572, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3003 - val_loss: 0.2657
# Epoch 26/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2835
# Epoch 00026: val_loss did not improve from 0.26572
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2833 - val_loss: 0.2662
# Epoch 27/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2802
# Epoch 00027: val_loss did not improve from 0.26572
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2801 - val_loss: 0.3124
# Epoch 28/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.3091
# Epoch 00028: val_loss did not improve from 0.26572
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.3100 - val_loss: 0.3115
# Epoch 29/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2965
# Epoch 00029: val_loss improved from 0.26572 to 0.25469, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2962 - val_loss: 0.2547
# Epoch 30/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2757
# Epoch 00030: val_loss improved from 0.25469 to 0.25307, saving model to autoencoder.h5
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2754 - val_loss: 0.2531
# Epoch 31/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2541
# Epoch 00031: val_loss did not improve from 0.25307
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2540 - val_loss: 0.2565
# Epoch 32/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2571
# Epoch 00032: val_loss did not improve from 0.25307
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2568 - val_loss: 0.2728
# Epoch 33/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2625
# Epoch 00033: val_loss did not improve from 0.25307
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2623 - val_loss: 0.2580
# Epoch 34/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2462
# Epoch 00034: val_loss did not improve from 0.25307
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2460 - val_loss: 0.2632
# Epoch 35/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2418
# Epoch 00035: val_loss improved from 0.25307 to 0.25116, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2419 - val_loss: 0.2512
# Epoch 36/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2533
# Epoch 00036: val_loss did not improve from 0.25116
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2530 - val_loss: 0.2637
# Epoch 37/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2443
# Epoch 00037: val_loss improved from 0.25116 to 0.24419, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2441 - val_loss: 0.2442
# Epoch 38/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2447
# Epoch 00038: val_loss did not improve from 0.24419
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2447 - val_loss: 0.2658
# Epoch 39/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2516
# Epoch 00039: val_loss did not improve from 0.24419
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2514 - val_loss: 0.2566
# Epoch 40/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2523
# Epoch 00040: val_loss improved from 0.24419 to 0.22762, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2522 - val_loss: 0.2276
# Epoch 41/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2331
# Epoch 00041: val_loss did not improve from 0.22762
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2329 - val_loss: 0.2450
# Epoch 42/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2265
# Epoch 00042: val_loss improved from 0.22762 to 0.22640, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2264 - val_loss: 0.2264
# Epoch 43/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2192
# Epoch 00043: val_loss did not improve from 0.22640
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2194 - val_loss: 0.2336
# Epoch 44/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2385
# Epoch 00044: val_loss improved from 0.22640 to 0.22391, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2383 - val_loss: 0.2239
# Epoch 45/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2413
# Epoch 00045: val_loss did not improve from 0.22391
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2416 - val_loss: 0.2480
# Epoch 46/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2543
# Epoch 00046: val_loss did not improve from 0.22391
# 16535/16535 [==============================] - 23s 1ms/sample - loss: 0.2541 - val_loss: 0.2802
# Epoch 47/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2740
# Epoch 00047: val_loss did not improve from 0.22391
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2737 - val_loss: 0.2297
# Epoch 48/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2345
# Epoch 00048: val_loss did not improve from 0.22391
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2342 - val_loss: 0.2288
# Epoch 49/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2277
# Epoch 00049: val_loss did not improve from 0.22391
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2274 - val_loss: 0.2300
# Epoch 50/50
# 16512/16535 [============================>.] - ETA: 0s - loss: 0.2319
# Epoch 00050: val_loss improved from 0.22391 to 0.22323, saving model to autoencoder.h5
# 16535/16535 [==============================] - 24s 1ms/sample - loss: 0.2318 - val_loss: 0.2232
# train time :  1182.5645272
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   if __name__ == '__main__':

# %%
# test_df_http = test_df[test_df['service'] == 21]
test_df_http = test_df

# %%
# 代表异常的二进制指示符
status = pd.Series([0 if i == 0 else 1 for i in test_df_http['label']])
window_size = 10
test_labels = [1 if np.sum(status[i : i + window_size]) > 0 else 0 for i in range(0, len(status)-window_size + 1, 5)]

# 删除所有分类列
test_df_http.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'label'], axis = 1, inplace = True)
# 删除无标准偏差的列
test_df_http.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'lsu_attempted', 'lnum_file_creations', 'lnum_outbound_cmds'], axis = 1, inplace = True)

test_df_http = pd.DataFrame(scaler.transform(test_df_http), columns = test_df_http.columns)
test_df_http_pca = pd.DataFrame(pca.transform(test_df_http), columns = pca_cols)

# %%
# 从测试数据中提取窗口
test_windows = get_windows(test_df_http_pca, window_size = 10, stride = 5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 62204/62204 [00:06<00:00, 9719.48it/s]

# %%
# 使用已训练过的自编码器对测试窗口进行重构
# 测试用时
start_time=time.clock()
test_windows_pred = autoencoder_loaded.predict(test_windows)
end_time=time.clock()

print("test time : ", (end_time - start_time))
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# test time :  27.839603699999998
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """

# %%
test_windows_pred.shape
# Out:
# (62204, 10, 12)

# %%
# 为每个窗口计算重构误差
# 在tensorflow中实现，以便在gpu可用时更快地执行
def get_recon_erros(true_windows, pred_windows) :
  recon_errors = []

  def cond(y_true, y_pred, i, iters) :
    return tf.less(i, iters)

  def body(y_true, y_pred, i, iters) :
    tensor_for_error = tf.math.subtract(tf.slice(y_true, [i, 0, 0], [1, -1, -1]), tf.slice(y_pred, [i, 0, 0], [1, -1, -1]))
    tensor_for_error = tf.reshape(tensor_for_error, [window_size, 12])

    recon_error = tf.math.reduce_mean(tf.norm(tensor_for_error, ord = 'euclidean', axis = 1))
    recon_errors.append(recon_error.numpy())

    return [y_true, y_pred, tf.add(i, 1), iters]

  iters = tf.constant(len(true_windows))

  result = tf.while_loop(cond, body, [tf.constant(true_windows.astype(np.float32)), tf.constant(pred_windows.astype(np.float32)), 0, iters])
  return recon_errors

recon_errors = get_recon_erros(test_windows, test_windows_pred)
recon_errors = np.array(recon_errors).reshape(-1, 1)

# 将重构误差放缩到[0, 1]之间
mm_scaler = MinMaxScaler()
anomaly_scores = mm_scaler.fit_transform(recon_errors).flatten()

# %%
plt.figure(figsize = (20, 10))
plt.plot(test_labels, c = 'blue', label = 'original')
plt.plot(anomaly_scores, c = 'red', label = 'predicted')
plt.yticks(np. arange(0, 1.1, 0.1))
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.grid()
plt.legend()
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(test_labels, anomaly_scores)
auc = roc_auc_score(test_labels, anomaly_scores)


# ROC
plt.figure(figsize = (10, 5))
plt.plot([0, 1], [0, 1], color = 'black', linestyle = '--')
plt.plot(fpr, tpr, label = 'AUC={}'.format(auc))
plt.grid()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.title('ROC')
plt.show()

# %%
anomaly_combinations = [(anomaly_scores > i).astype(np.int32) for i in thresholds]
f1_scores = [f1_score(test_labels, i) for i in anomaly_combinations]

# F1 score vs Thresholds
plt.figure(figsize = (10, 5))
plt.plot(thresholds, f1_scores)
plt.grid()
plt.xlabel('Thresholds')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Thresholds')
plt.show()

# %%
# 产生最佳F1分数的阈值
max_f1_score = np.max(f1_scores)
best_threshold = thresholds[f1_scores.index(max_f1_score)]
print('best threshold = {}'.format(best_threshold))
# Out:
# best threshold = 0.005443147383630276

# %%
# 对于上述阈值的混淆矩阵
anomaly_indicator = (anomaly_scores > best_threshold).astype(np.int32)
confusion_matrix(test_labels, anomaly_indicator)
# Out:
# array([[ 2337,  3698],
#        [ 1558, 54611]], dtype=int64)

# %%
(2337 + 54611) / (2337 + 54611 + 3698 + 1558)
# Out:
# 0.9155038261205067

# %%
precision = precision_score(test_labels, anomaly_indicator)
precision
# Out:
# 0.9365792587765182

# %%
recall = recall_score(test_labels, anomaly_indicator)
recall
# Out:
# 0.9722622799052858

# %%
f1_sc = f1_score(test_labels, anomaly_indicator)
f1_sc
# Out:
# 0.9540872482048953

# %%
accuracy_sc = accuracy_score(test_labels, anomaly_indicator)
accuracy_sc
# Out:
# 0.9155038261205067

# %%
plt.figure(figsize = (20, 10))
sns.scatterplot(x = np.arange(0, len(anomaly_scores)), y = anomaly_scores, hue = ['normal' if i == 0 else 'anomaly' for i in anomaly_indicator], palette = ['blue', 'red'], legend = 'full')
plt.axhline(y = best_threshold, label = 'threshold')
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.legend()
plt.grid()
plt.show()
