# %%
import tqdm
import time
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, OneHotEncoder
from mpl_toolkits import mplot3d
from tensorflow.keras.layers import Input, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
from scipy.spatial.distance import euclidean
import random
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix

# %%
first = time.clock()
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
# 手动添加特征，训练集42，测试集41

feather = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 
           'num_failed_logins', 'logged_in', 'lnum_compromised', 'lroot_shell', 'lsu_attempted', 'lnum_root', 'lnum_file_creations', 
           'lnum_shells', 'lnum_access_files', 'lnum_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 
           'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 
           'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 
           'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'label']

# %%
# TRAIN_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\UNSW-NB 15\\UNSW_NB15_training-set.csv'
TRAIN_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\kddcup\\train_10_percent_kddcup.csv'
TEST_DATA_PATH = 'C:\\Users\\Qin\\Desktop\\kddcup\\test_10_percent_kddcup.csv'

# %%
train_df = pd.read_csv(TRAIN_DATA_PATH, header = None, names = feather)
test_df = pd.read_csv(TEST_DATA_PATH, header = None, names = feather)
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# train
pd.value_counts(train_df['label']).plot(kind = 'bar', figsize = (20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize = 13)
plt.grid()
plt.show()

# %%
train_df_http = train_df[train_df['service'] == 21]

# %%
pd.value_counts(train_df_http['label']).plot(kind = 'bar', figsize = (20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize = 13)
plt.grid()
plt.show()

# %%
train_normal_instances = train_df_http[train_df_http['label'] == 0].shape[0]
train_anomalous_instances = train_df_http[train_df_http['label'] != 0].shape[0]

# 只提取属于"normal"的实例
train_df_http_normal = train_df_http[train_df_http['label'] == 0]

# 删除所有分类列
train_df_http_normal.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'label'], axis = 1, inplace = True)
# 删除无标准偏差的列
train_df_http_normal.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'lsu_attempted', 'lnum_file_creations', 'lnum_outbound_cmds'], axis = 1, inplace = True)


train_df_http_normal.boxplot(figsize = (20, 10))
plt.show()
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# train
# 热图，描述各个特征之间存在的相关性
scaler = StandardScaler()
train_df_http_normal = pd.DataFrame(scaler.fit_transform(train_df_http_normal), columns = train_df_http_normal.columns)

plt.figure(figsize = (15, 10))
sns.heatmap(train_df_http_normal.corr(), cmap = 'viridis')
plt.show()

# %%
# train
# 采用主成分分析法对数据进行降维，覆盖原始数据80%的方差
# ｎ＿components：指定希望PCA降维后的特征维度数目
# 最常用的做法是直接指定降维到的维度数目，此时n_components是一个大于等于1的整数。
# 当然，我们也可以指定主成分的方差和所占的最小比例阈值，让PCA类自己去根据样本特征方差来决定降维到的维度数，
# 此时n_components是一个（0，1]之间的数。
pca = PCA(n_components = 0.8)
pca.fit(train_df_http_normal)

pca_cols = ['PCA_' + str(i) for i in range(pca.n_components_)]
train_df_pca = pd.DataFrame(pca.transform(train_df_http_normal), columns = pca_cols)

# %%
train_df_http_normal.shape
# Out:
# (61886, 28)

# %%
train_df_pca.shape
# Out:
# (61886, 13)

# %%
# 采用特定的窗口长度和步长从数据中提取窗口
def get_windows(df, window_size = 10, stride = 5) :
    windows_arr = []
    for i in tqdm.tqdm(range(0, len(df) - window_size + 1, stride)) :
        windows_arr.append(df.iloc[i : i + window_size, : ].to_numpy())
        
    return np.array(windows_arr)

# %%
K.clear_session()

# 带堆叠LSTM的编码器模型
window_size = 10
encoder = Sequential([LSTM(80, return_sequences = True, activation = 'selu', input_shape = (window_size, 13), dropout = 0.2), 
                      LSTM(50, activation = 'selu', return_sequences = True), 
                      LSTM(20, activation = 'selu')], name = 'encoder')


# 输出维与输入维相同的解码器模型
decoder = Sequential([RepeatVector(window_size), 
                      LSTM(50, activation = 'selu', return_sequences = True), 
                      LSTM(80, activation = 'selu', return_sequences = True), 
                      TimeDistributed(Dense(13, activation = 'linear'))], name = 'decoder')

# 使用编码器、解码器作为层创建顺序自动编码器
autoencoder = Sequential([encoder, decoder], name = 'autoencoder')
autoencoder.compile(optimizer = 'adam', loss = tf.keras.losses.Huber(100.))
autoencoder.summary()

encoder.summary()
decoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Sequential)         (None, 20)                61960
# _________________________________________________________________
# decoder (Sequential)         (None, 10, 13)            57173
# =================================================================
# Total params: 119,133
# Trainable params: 119,133
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 80)            30080
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 50)            26200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20)                5680
# =================================================================
# Total params: 61,960
# Trainable params: 61,960
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# repeat_vector (RepeatVector) (None, 10, 20)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 50)            14200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10, 80)            41920
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 13)            1053
# =================================================================
# Total params: 57,173
# Trainable params: 57,173
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 训练自编码器
# 训练时使用模型checkpoint回调，以保证在验证集上具有最佳性能的模型和权重
check_point = tf.keras.callbacks.ModelCheckpoint('autoencoder.h5', monitor = 'val_loss', save_best_only = True, mode = 'min', verbose = 1)
windows_shuffled = get_windows(train_df_pca)

# 记录训练时间
start_time=time.clock()
train_hist = autoencoder.fit(windows_shuffled, windows_shuffled[:, :, ::-1], batch_size = 64, validation_split = 0.15, epochs = 50, callbacks = [check_point])
end_time=time.clock()

print("train time : ", (end_time - start_time))

# 用最佳权重集加载自动编码器
autoencoder_loaded = tf.keras.models.load_model('autoencoder.h5')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 12376/12376 [00:01<00:00, 9076.86it/s]
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# Train on 10519 samples, validate on 1857 samples
# Epoch 1/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.5693
# Epoch 00001: val_loss improved from inf to 0.74968, saving model to autoencoder.h5
# 10519/10519 [==============================] - 20s 2ms/sample - loss: 0.5687 - val_loss: 0.7497
# Epoch 2/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00002: val_loss improved from 0.74968 to 0.72739, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.5468 - val_loss: 0.7274
# Epoch 3/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.5071
# Epoch 00003: val_loss improved from 0.72739 to 0.71590, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.5064 - val_loss: 0.7159
# Epoch 4/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4945
# Epoch 00004: val_loss improved from 0.71590 to 0.70262, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4945 - val_loss: 0.7026
# Epoch 5/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.5232
# Epoch 00005: val_loss improved from 0.70262 to 0.69089, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.5224 - val_loss: 0.6909
# Epoch 6/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4878- ETA:
# Epoch 00006: val_loss improved from 0.69089 to 0.67177, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4870 - val_loss: 0.6718
# Epoch 7/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4812
# Epoch 00007: val_loss did not improve from 0.67177
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4810 - val_loss: 0.6931
# Epoch 8/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4772- ETA:
# Epoch 00008: val_loss improved from 0.67177 to 0.64995, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4767 - val_loss: 0.6500
# Epoch 9/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4672
# Epoch 00009: val_loss did not improve from 0.64995
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4667 - val_loss: 0.6584
# Epoch 10/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4628
# Epoch 00010: val_loss did not improve from 0.64995
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4623 - val_loss: 0.6542
# Epoch 11/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4576
# Epoch 00011: val_loss improved from 0.64995 to 0.64794, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4574 - val_loss: 0.6479
# Epoch 12/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4543
# Epoch 00012: val_loss improved from 0.64794 to 0.62903, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4539 - val_loss: 0.6290
# Epoch 13/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4469
# Epoch 00013: val_loss did not improve from 0.62903
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4464 - val_loss: 0.6526
# Epoch 14/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4516
# Epoch 00014: val_loss improved from 0.62903 to 0.62801, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 2ms/sample - loss: 0.4509 - val_loss: 0.6280
# Epoch 15/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4346
# Epoch 00015: val_loss did not improve from 0.62801
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4341 - val_loss: 0.6464
# Epoch 16/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4409
# Epoch 00016: val_loss did not improve from 0.62801
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4402 - val_loss: 0.6373
# Epoch 17/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4275
# Epoch 00017: val_loss improved from 0.62801 to 0.62067, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 2ms/sample - loss: 0.4269 - val_loss: 0.6207
# Epoch 18/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4203
# Epoch 00018: val_loss improved from 0.62067 to 0.61331, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.4197 - val_loss: 0.6133
# Epoch 19/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4175
# Epoch 00019: val_loss did not improve from 0.61331
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4169 - val_loss: 0.6771
# Epoch 20/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4114
# Epoch 00020: val_loss improved from 0.61331 to 0.60715, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4108 - val_loss: 0.6071
# Epoch 21/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4130
# Epoch 00021: val_loss improved from 0.60715 to 0.59824, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4133 - val_loss: 0.5982
# Epoch 22/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4100
# Epoch 00022: val_loss did not improve from 0.59824
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4093 - val_loss: 0.6200
# Epoch 23/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3903
# Epoch 00023: val_loss did not improve from 0.59824
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3902 - val_loss: 0.6235
# Epoch 24/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3936
# Epoch 00024: val_loss improved from 0.59824 to 0.58239, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3936 - val_loss: 0.5824
# Epoch 25/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4047
# Epoch 00025: val_loss did not improve from 0.58239
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4050 - val_loss: 0.6454
# Epoch 26/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4224
# Epoch 00026: val_loss did not improve from 0.58239
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4216 - val_loss: 0.6080
# Epoch 27/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3889
# Epoch 00027: val_loss did not improve from 0.58239
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3884 - val_loss: 0.6056
# Epoch 28/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3768
# Epoch 00028: val_loss did not improve from 0.58239
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3764 - val_loss: 0.5924
# Epoch 29/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3700
# Epoch 00029: val_loss did not improve from 0.58239
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3696 - val_loss: 0.6041
# Epoch 30/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3892
# Epoch 00030: val_loss improved from 0.58239 to 0.57507, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3889 - val_loss: 0.5751
# Epoch 31/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3831
# Epoch 00031: val_loss improved from 0.57507 to 0.57385, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3827 - val_loss: 0.5739
# Epoch 32/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3977
# Epoch 00032: val_loss improved from 0.57385 to 0.54777, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3974 - val_loss: 0.5478
# Epoch 33/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3472
# Epoch 00033: val_loss did not improve from 0.54777
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3475 - val_loss: 0.5609
# Epoch 34/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3626
# Epoch 00034: val_loss improved from 0.54777 to 0.54387, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3621 - val_loss: 0.5439
# Epoch 35/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3672
# Epoch 00035: val_loss did not improve from 0.54387
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3666 - val_loss: 0.5703
# Epoch 36/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3381
# Epoch 00036: val_loss did not improve from 0.54387
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3377 - val_loss: 0.5585
# Epoch 37/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3404
# Epoch 00037: val_loss improved from 0.54387 to 0.52891, saving model to autoencoder.h5
# 10519/10519 [==============================] - 16s 1ms/sample - loss: 0.3403 - val_loss: 0.5289
# Epoch 38/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3422
# Epoch 00038: val_loss did not improve from 0.52891
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3435 - val_loss: 0.5981
# Epoch 39/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3527
# Epoch 00039: val_loss did not improve from 0.52891
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3527 - val_loss: 0.5309
# Epoch 40/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3207
# Epoch 00040: val_loss did not improve from 0.52891
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3203 - val_loss: 0.5384
# Epoch 41/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3406
# Epoch 00041: val_loss did not improve from 0.52891
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3403 - val_loss: 0.5524
# Epoch 42/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3161
# Epoch 00042: val_loss improved from 0.52891 to 0.49778, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3158 - val_loss: 0.4978
# Epoch 43/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.2990
# Epoch 00043: val_loss improved from 0.49778 to 0.47944, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.2995 - val_loss: 0.4794
# Epoch 44/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3161
# Epoch 00044: val_loss did not improve from 0.47944
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3157 - val_loss: 0.5447
# Epoch 45/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.2913
# Epoch 00045: val_loss did not improve from 0.47944
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.2909 - val_loss: 0.4859
# Epoch 46/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.2698
# Epoch 00046: val_loss did not improve from 0.47944
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.2697 - val_loss: 0.5286
# Epoch 47/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.3508
# Epoch 00047: val_loss improved from 0.47944 to 0.45430, saving model to autoencoder.h5
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.3504 - val_loss: 0.4543
# Epoch 48/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.2805
# Epoch 00048: val_loss did not improve from 0.45430
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.2802 - val_loss: 0.5139
# Epoch 49/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.2757
# Epoch 00049: val_loss did not improve from 0.45430
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.2754 - val_loss: 0.5006
# Epoch 50/50
# 10496/10519 [============================>.] - ETA: 0s - loss: 0.4381
# Epoch 00050: val_loss did not improve from 0.45430
# 10519/10519 [==============================] - 15s 1ms/sample - loss: 0.4373 - val_loss: 0.5391
# train time :  775.7794268
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   if __name__ == '__main__':

# %%
test_df_http = test_df

# %%
# 代表异常的二进制指示符
status = pd.Series([0 if i == 0 else 1 for i in test_df_http['label']])
window_size = 10
test_labels = [1 if np.sum(status[i : i + window_size]) > 0 else 0 for i in range(0, len(status)-window_size + 1, 5)]

# 删除所有分类列
test_df_http.drop(['protocol_type', 'service', 'flag', 'land', 'logged_in', 'is_host_login', 'is_guest_login', 'label'], axis = 1, inplace = True)
# 删除无标准偏差的列
test_df_http.drop(['wrong_fragment', 'urgent', 'num_failed_logins', 'lsu_attempted', 'lnum_file_creations', 'lnum_outbound_cmds'], axis = 1, inplace = True)

test_df_http = pd.DataFrame(scaler.transform(test_df_http), columns = test_df_http.columns)
test_df_http_pca = pd.DataFrame(pca.transform(test_df_http), columns = pca_cols)

# %%
# 从测试数据中提取窗口
test_windows = get_windows(test_df_http_pca, window_size = 10, stride = 5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 62204/62204 [00:07<00:00, 8721.81it/s]

# %%
# 使用已训练过的自编码器对测试窗口进行重构
# 测试用时
start_time=time.clock()
test_windows_pred = autoencoder_loaded.predict(test_windows)
end_time=time.clock()

print("test time : ", (end_time - start_time))
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# test time :  29.806397999999945
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """

# %%
test_windows_pred.shape
# Out:
# (62204, 10, 13)

# %%
# 为每个窗口计算重构误差
# 在tensorflow中实现，以便在gpu可用时更快地执行
def get_recon_erros(true_windows, pred_windows) :
  recon_errors = []

  def cond(y_true, y_pred, i, iters) :
    return tf.less(i, iters)

  def body(y_true, y_pred, i, iters) :
    tensor_for_error = tf.math.subtract(tf.slice(y_true, [i, 0, 0], [1, -1, -1]), tf.slice(y_pred, [i, 0, 0], [1, -1, -1]))
    tensor_for_error = tf.reshape(tensor_for_error, [window_size, 13])

    recon_error = tf.math.reduce_mean(tf.norm(tensor_for_error, ord = 'euclidean', axis = 1))
    recon_errors.append(recon_error.numpy())

    return [y_true, y_pred, tf.add(i, 1), iters]

  iters = tf.constant(len(true_windows))

  result = tf.while_loop(cond, body, [tf.constant(true_windows.astype(np.float32)), tf.constant(pred_windows.astype(np.float32)), 0, iters])
  return recon_errors

recon_errors = get_recon_erros(test_windows, test_windows_pred)
recon_errors = np.array(recon_errors).reshape(-1, 1)

# 将重构误差放缩到[0, 1]之间
mm_scaler = MinMaxScaler()
anomaly_scores = mm_scaler.fit_transform(recon_errors).flatten()

# %%
plt.figure(figsize = (20, 10))
plt.plot(test_labels, c = 'blue', label = 'original')
plt.plot(anomaly_scores, c = 'red', label = 'predicted')
plt.yticks(np. arange(0, 1.1, 0.1))
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.grid()
plt.legend()
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(test_labels, anomaly_scores)
auc = roc_auc_score(test_labels, anomaly_scores)


# ROC
plt.figure(figsize = (10, 5))
plt.plot([0, 1], [0, 1], color = 'black', linestyle = '--')
plt.plot(fpr, tpr, label = 'AUC={}'.format(auc))
plt.grid()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.title('ROC')
plt.show()

# %%
anomaly_combinations = [(anomaly_scores > i).astype(np.int32) for i in thresholds]
f1_scores = [f1_score(test_labels, i) for i in anomaly_combinations]

# F1 score vs Thresholds
plt.figure(figsize = (10, 5))
plt.plot(thresholds, f1_scores)
plt.grid()
plt.xlabel('Thresholds')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Thresholds')
plt.show()

# %%
# 产生最佳F1分数的阈值
max_f1_score = np.max(f1_scores)
best_threshold = thresholds[f1_scores.index(max_f1_score)]
print('best threshold = {}'.format(best_threshold))
# Out:
# best threshold = 4.862260539084673e-05

# %%
# 对于上述阈值的混淆矩阵
anomaly_indicator = (anomaly_scores > best_threshold).astype(np.int32)
confusion_matrix(test_labels, anomaly_indicator)
# Out:
# array([[  627,  5408],
#        [  455, 55714]], dtype=int64)

# %%
(627 + 55714) / (627 + 5408 + 455 + 55714)
# Out:
# 0.9057456112147129

# %%
precision = precision_score(test_labels, anomaly_indicator)
precision
# Out:
# 0.9115212198553713

# %%
recall = recall_score(test_labels, anomaly_indicator)
recall
# Out:
# 0.991899446313803

# %%
f1_sc = f1_score(test_labels, anomaly_indicator)
f1_sc
# Out:
# 0.950013214995183

# %%
accuracy_sc = accuracy_score(test_labels, anomaly_indicator)
accuracy_sc
# Out:
# 0.9057456112147129

# %%
second = time.clock()
# Out:
# C:\Users\Qin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
print('time : ', (second - first))
# Out:
# time :  1297.9937398

# %%
plt.figure(figsize = (20, 10))
sns.scatterplot(x = np.arange(0, len(anomaly_scores)), y = anomaly_scores, hue = ['normal' if i == 0 else 'anomaly' for i in anomaly_indicator], palette = ['blue', 'red'], legend = 'full')
plt.axhline(y = best_threshold, label = 'threshold')
plt.xlabel('samples')
plt.ylabel('anomaly score')
plt.legend()
plt.grid()
plt.show()
